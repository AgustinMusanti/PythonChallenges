# %% [markdown]
# # 1) Crear series a partir de listas y a partir de arrays.

# %%
import pandas as pd
import numpy as np

# Serie desde una lista

lista = [10, 20, 30, 40]
serieLista = pd.Series(lista)
print("Serie desde lista:")
print(serieLista)

# Serie desde un array de numpy

array = np.array([5, 15, 25, 35])
serieArray = pd.Series(array)
print("\nSerie desde array:")
print(serieArray)
# Out:
# Serie desde lista:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
#
# Serie desde array:
# 0     5
# 1    15
# 2    25
# 3    35
# dtype: int32

# %% [markdown]
# # 2) Crear dataframes a partir de listas anidadas, y de arrays anidados.

# %%
# DataFrame desde listas anidadas

ListasAnidadas = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
dfListas = pd.DataFrame(ListasAnidadas)
print("\nDataFrame desde listas anidadas:")
print(dfListas)
# Out:
# DataFrame desde listas anidadas:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
# DataFrame desde arrays anidados

ArraysAnidados = np.array([[10, 20, 30], [40, 50, 60], [70, 80, 90]])
dfArrays = pd.DataFrame(ArraysAnidados)
print("\nDataFrame desde arrays anidados:")
print(dfArrays)
# Out:
# DataFrame desde arrays anidados:
#     0   1   2
# 0  10  20  30
# 1  40  50  60
# 2  70  80  90

# %% [markdown]
# # 3) Crear dataframes especificando etiquetas para las columnas.

# %%
# DataFrame con etiquetas para las columnas (utilizo nombres de meses para el ejemplo)

dfEtiquetas = pd.DataFrame(ArraysAnidados, columns=["Enero", "Febrero", "Marzo"])
print("\nDataFrame con etiquetas para las columnas:")
print(dfEtiquetas)
# Out:
# DataFrame con etiquetas para las columnas:
#    Enero  Febrero  Marzo
# 0     10       20     30
# 1     40       50     60
# 2     70       80     90

# %% [markdown]
# # 4) Cargar el dataframe del titanic(titanic.csv), y visualizar la información del mismo.

# %%
import pandas as pd

Titanic = pd.read_csv("titanic.csv")

# Visualizo las primeras filas del dataframe con "Head"

Titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Observo la información general del dataframe con "Info"

Titanic.info()

# Puedo ver un resumen estadístico del dataframe con "Describe"

print("\nResumen estadístico del dataframe:")
print(Titanic.describe())

# Por último, puedo listar los nombres de las columnas con "Columns"

print("\nNombres de las columnas del dataframe:")
print(Titanic.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#
# Resumen estadístico del dataframe:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# ...

# %% [markdown]
# # 5) Seleccionar las columnas “Survived”, “Pclass”, “Age” y “Sex”

# %%
Titanic[["Survived", "Pclass", "Sex", "Age"]]
# Out:
#      Survived  Pclass     Sex   Age
# 0           0       3    male  22.0
# 1           1       1  female  38.0
# 2           1       3  female  26.0
# 3           1       1  female  35.0
# 4           0       3    male  35.0
# ..        ...     ...     ...   ...
# 886         0       2    male  27.0
# 887         1       1  female  19.0
# 888         0       3  female   NaN
# 889         1       1    male  26.0
# 890         0       3    male  32.0
#
# [891 rows x 4 columns]

# %% [markdown]
# # 6) Seleccionar las filas 200 a 400 de las columnas “Name” y “Age”

# %%
Ejercicio6 = Titanic.loc[200:400, ["Name", "Age"]]

Ejercicio6
# Out:
#                                  Name   Age
# 200    Vande Walle, Mr. Nestor Cyriel  28.0
# 201               Sage, Mr. Frederick   NaN
# 202        Johanson, Mr. Jakob Alfred  34.0
# 203              Youseff, Mr. Gerious  45.5
# 204          Cohen, Mr. Gurshon "Gus"  18.0
# ..                                ...   ...
# 396               Olsson, Miss. Elina  31.0
# 397           McKane, Mr. Peter David  46.0
# 398                  Pain, Dr. Alfred  23.0
# 399  Trout, Mrs. William H (Jessie L)  28.0
# 400                Niskanen, Mr. Juha  39.0
#
# [201 rows x 2 columns]

# %% [markdown]
# # 7) Cambiar el nombre de la columna “PassengerId” por “ID”.

# %%
Titanic.rename(columns={"PassengerId": "ID"}, inplace=True)

# Verifico que el cambio se haya efectuado

Titanic.head()
# Out:
#    ID  Survived  Pclass                                               Name  \
# 0   1         0       3                            Braund, Mr. Owen Harris
# 1   2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   3         1       3                             Heikkinen, Miss. Laina
# 3   4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4   5         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %% [markdown]
# # 8) Seleccionar los datos de todas las mujeres de primera clase.

# %%
# Filtro las filas donde 'Sex' es 'female' y 'Pclass' es 1 (primera clase)

MujeresPrimeraClase = Titanic[(Titanic['Sex'] == 'female') & (Titanic['Pclass'] == 1)]

MujeresPrimeraClase
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 9) Seleccionar los datos de los varones menores de edad de segunda clase.

# %%
# En este caso, tomo como menores de edad a aquellos qe posean menos de 13 años.

# Filtro las filas donde 'Sex' es 'male', 'Age' es menor a 13 y 'Pclass' es 2 (segunda clase)

Varones2daClase = Titanic[(Titanic['Sex'] == 'male') & (Titanic['Age'] < 13) & (Titanic['Pclass'] == 2)]

Varones2daClase
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates  male
# 183          184         1       2        Becker, Master. Richard F  male
# 193          194         1       2       Navratil, Master. Michel M  male
# 340          341         1       2   Navratil, Master. Edmond Roger  male
# 407          408         1       2   Richards, Master. William Rowe  male
# 549          550         1       2   Davies, Master. John Morgan Jr  male
# 755          756         1       2        Hamalainen, Master. Viljo  male
# 827          828         1       2            Mallet, Master. Andre  male
# 831          832         1       2  Richards, Master. George Sibley  male
#
#       Age  SibSp  Parch           Ticket     Fare Cabin Embarked
# 78   0.83      0      2           248738  29.0000   NaN        S
# 183  1.00      2      1           230136  39.0000    F4        S
# ...

# %% [markdown]
# # 10) Encontrar el promedio de edad de hombres y de las mujeres

# %%
# Calculo el promedio de edad para hombres y mujeres. Al usar "Group By" agrupo los géneros

PromedioEdad = Titanic.groupby('Sex')['Age'].mean()

PromedioEdad
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %% [markdown]
# # 11) Encontrar la cantidad de sobrevivientes de hombres y las mujeres.

# %%
# Agrupo por 'Sex' y cuento la cantidad de sobrevivientes. En este df = Survived == 1

CantidadSobrevivientes = Titanic[Titanic['Survived'] == 1].groupby('Sex').size()

CantidadSobrevivientes
# Out:
# Sex
# female    233
# male      109
# dtype: int64

# %% [markdown]
# ## Aclaración: Este dataframe (titanic.csv) no contiene realmente toda la información de los que viajaban en el barco, sino que es una porción de los pasajeros. Pero para cuestiones prácticas y académicas es uno de los más utilizados y empleados para aprender a usar estas herramientas.
